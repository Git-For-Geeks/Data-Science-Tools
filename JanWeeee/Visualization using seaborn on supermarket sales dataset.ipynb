# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

# %%
from google.colab import drive

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df=pd.read_csv('/content/drive/My Drive/dh&v lab/supermarket_sales.csv',sep=',',header='infer')
df
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# 0         Health and beauty       74.69         7  26.1415   548.9715
# 1    Electronic accessories       15.28         5   3.8200    80.2200
# ...

# %% [markdown]
# #1. Load the dataset and describe its detailed information: (size, shape, datatypes etc.)

# %%
x=df.shape
y=df.size
print(x)
print(y)
# Out:
# (1000, 17)
# 17000

# %%
df.dtypes
# Out:
# Invoice ID                  object
# Branch                      object
# City                        object
# Customer type               object
# Gender                      object
# Product line                object
# Unit price                 float64
# Quantity                     int64
# Tax 5%                     float64
# Total                      float64
# Date                        object
# Time                        object
# Payment                     object
# cogs                       float64
# gross margin percentage    float64
# gross income               float64
# Rating                     float64
# dtype: object

# %% [markdown]
# #2. Change the datatype of ‘Date’ to datetime format.

# %%
# converting the 'Date' column to datetime format
df['Date']= pd.to_datetime(df['Date'])

# Checking the format of 'Date' column
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Invoice ID               1000 non-null   object
#  1   Branch                   1000 non-null   object
#  2   City                     1000 non-null   object
#  3   Customer type            1000 non-null   object
#  4   Gender                   1000 non-null   object
#  5   Product line             1000 non-null   object
#  6   Unit price               1000 non-null   float64
#  7   Quantity                 1000 non-null   int64
#  8   Tax 5%                   1000 non-null   float64
#  9   Total                    1000 non-null   float64
#  10  Date                     1000 non-null   datetime64[ns]
#  11  Time                     1000 non-null   object
#  12  Payment                  1000 non-null   object
# ...

# %% [markdown]
# #3. Find the duration when the maximum number of quantity sold using lineplot.

# %%
df['month'] = pd.DatetimeIndex(df['Date']).month
sns.lineplot(x="Quantity", y = 'month', data = df, color = 'pink').set_title("Product sales per hour")
# Out:
# Text(0.5, 1.0, 'Product sales per hour')

# %% [markdown]
# #4. Find the distribution of branch’s sales quantity per hour in a monthly fashion in function Gender type (Female / male) Use maximum parameters and allocate the proper value in them.

# %%
df['Hour'] = pd.to_datetime(df['Time']).dt.hour
sns.barplot(x="Quantity", y="Hour", hue="Gender", data=df, color='skyblue')

# %% [markdown]
# #5. Find the distribution of branch’s sales quantity per hour in a monthly fashion in function Customer type (member/normal) Use maximum parameters and allocate the proper value in them.

# %%
sns.barplot(x="Quantity", y="month", hue="Customer type", data=df)

# %% [markdown]
# #6.Plot the histogram for all the attributes and DRAW CONCLUSION

# %%
df.hist(bins=30, figsize=(15, 10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f4d4b1edf90>,
# ...
#       dtype=object)

# %% [markdown]
# #7. Show the counterplot for attribute Branch and draw the conclusion.

# %%
a=sns.countplot(x ='Branch', data = df)
a.set(title="BRANCH COUNTPLOT")
# Out:
# [Text(0.5, 1.0, 'BRANCH COUNTPLOT')]

# %% [markdown]
# #8. Find mostly used payment method using countplot and write the analysis.

# %%
b=sns.countplot(x ='Payment', data = df)
b.set(title="payment countplot")
# Out:
# [Text(0.5, 1.0, 'payment countplot')]

# %% [markdown]
# #9. Draw the boxplot between the attributes Branch and Ratings and draw the analysis.

# %%
sns.boxplot(x='Branch', y='Rating', data=df)

# %% [markdown]
# #10. Draw the boxenplot for finding the relation between the product line and quantity and draw the conclusion.

# %%
sns.boxenplot(x="Product line", y="Quantity", data=df)

# %% [markdown]
# #11. Draw the swarmplot and show the relation between features &#39;Customer type&#39; and &#39;Rating&#39;

# %%
sns.swarmplot(x='Customer type', y='Rating', data=df)

# %% [markdown]
# #12. Find the normal distribution, binomial distribution, poison distribution for the randomly generated 50 values and visualize it using distance plot.

# %%
from numpy import random
sns.distplot(random.normal(size=50), hist=True)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
#Visualization of Binomial Distribution
from numpy import random
import matplotlib.pyplot as plt
import seaborn as sns

sns.distplot(random.binomial(n=10, p=0.5, size=50), hist=True, kde=False)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
#Visualization of Poisson Distribution
from numpy import random
import matplotlib.pyplot as plt
import seaborn as sns

sns.distplot(random.poisson(lam=2, size=50), kde=False)

plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# #13. Show the pairplot for the attributes such as gross income, quantity, unit price and ratings and DRAW CONCLUSION.

# %%
sns.pairplot(df, hue ='gross income')
plt.show()
#sns.pairplot(supersales_df, hue ='Quantity')
#sns.pairplot(supersales_df, hue ='Unit price')
#sns.pairplot(supersales_df, hue ='Rating')

# %% [markdown]
# #14. Find the correlation between all the columns and represent it using heatmap.

# %%
data = df
correlation = data.corr(method='pearson')
print(correlation)
# Out:
#                          Unit price  Quantity    Tax 5%     Total      cogs  \
# Unit price                 1.000000  0.010778  0.633962  0.633962  0.633962
# Quantity                   0.010778  1.000000  0.705510  0.705510  0.705510
# Tax 5%                     0.633962  0.705510  1.000000  1.000000  1.000000
# Total                      0.633962  0.705510  1.000000  1.000000  1.000000
# cogs                       0.633962  0.705510  1.000000  1.000000  1.000000
# gross margin percentage         NaN       NaN       NaN       NaN       NaN
# gross income               0.633962  0.705510  1.000000  1.000000  1.000000
# Rating                    -0.008778 -0.015815 -0.036442 -0.036442 -0.036442
# month                     -0.027387 -0.014524 -0.022301 -0.022301 -0.022301
#
#                          gross margin percentage  gross income    Rating  \
# Unit price                                   NaN      0.633962 -0.008778
# ...

# %%
sns.heatmap(np.round(df.corr(),2), annot=True)

# %% [markdown]
# #15. Generate the following 3 Plots as an output by setting the suitable parameters in countplot.

# %%
a=sns.countplot(x ='Payment', data = df,hue = 'Branch')
a.set(title="Payment Channel by branch")
# Out:
# [Text(0.5, 1.0, 'Payment Channel by branch')]

# %%
b=sns.countplot(x ='Gender', data = df)
b.set(title="Gender_Count")
# Out:
# [Text(0.5, 1.0, 'Gender_Count')]

# %%
c=sns.barplot(x ='Quantity',y = 'Product line',data = df,hue = 'Payment')
c.set(title="Payment per Product line")
# Out:
# [Text(0.5, 1.0, 'Payment per Product line')]
