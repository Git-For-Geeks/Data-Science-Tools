# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import drive

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# #1. Read Total profit of all months and show it using a line plot

# %%
dataset=pd.read_csv('/content/drive/My Drive/dh&v lab/company_sales_data.csv',sep=',',header='infer')
dataset.head()
# Out:
#    month_number  facecream  facewash  toothpaste  bathingsoap  shampoo  \
# 0             1       2500      1500        5200         9200     1200
# 1             2       2630      1200        5100         6100     2100
# 2             3       2140      1340        4550         9550     3550
# 3             4       3400      1130        5870         8870     1870
# 4             5       3600      1740        4560         7760     1560
#
#    moisturizer  total_units  total_profit
# 0         1500        21100        211000
# 1         1200        18330        183300
# 2         1340        22470        224700
# 3         1130        22270        222700
# 4         1740        20960        209600

# %%
dataset.columns
# Out:
# Index(['month_number', 'facecream', 'facewash', 'toothpaste', 'bathingsoap',
#        'shampoo', 'moisturizer', 'total_units', 'total_profit'],
#       dtype='object')

# %%
plt.figure(figsize=(7,5))
plt.plot('month_number', 'total_profit', data=dataset)
plt.xticks(dataset['month_number'].tolist())
plt.yticks([100000, 200000, 300000, 400000, 500000])
plt.grid()
plt.show()

# %% [markdown]
# **Analysis:** Above graph is drawn between total number of months and the total profit.
#
# The plt.xticks , plt.yticks functions are used to get and set the current tick locations and labels of the x-axis and y-axis.
#
# According to the graph the monthly profits are variable, in the 8th and 11th month profits are at peak and lowest in the 2nd month.
#
# Profits increased drastically from june to august and september to november

# %% [markdown]
# #2. Get total profit of all months and show line plot with the following Style properties.
# #Generated line plot must include following Style properties: –
#
#
# * Line Style dotted and Line-color should be red
# *Show legend at the lower right location.
# *X label name = Month Number
# *Y label name = Sold unit’s number
# *Add a circle marker.
# *Line marker color as red
# *Line width should be 3

# %%
plt.figure(figsize=(7,5))
plt.plot('month_number', 'total_profit', data=dataset, ls=':', c='r', marker='o', ms = 7,mfc = 'red', mec='black',
         label='Profit data of last year', lw=3)
plt.xticks(dataset['month_number'].tolist())
plt.yticks([100000, 200000, 300000, 400000, 500000])
plt.xlabel('Month Number')
plt.ylabel('Sold units number')
plt.legend(loc ='lower right')
plt.show()

# %% [markdown]
# **Analysis:** Above graph is drawn between total number of months and the total profit with some parameters
#
# The monthly profits are variable, in the 8th and 11th month profits are at peak and lowest in the 2nd month.
#
# Profits increased drastically from june to august and september to november

# %% [markdown]
# #3. Read all product sales data and show it using a multiline plot Display the number of units sold per month for each product using multiline plots. (i.e., Separate Plotline for each product).

# %%
plt.figure(figsize=(12,10))
plt.plot('month_number', 'facecream', data=dataset, label='Face Cream Sales Data',c='skyblue', marker='o',mec='black', linewidth=3)
plt.plot('month_number', 'facewash', data=dataset, label='Face Wash Sales Data',c='grey', marker='o',mec='black', linewidth=3)
plt.plot('month_number', 'toothpaste', data=dataset, label='Toothpaste Sales Data',c='purple', marker='o',mec='black', linewidth=3)
plt.plot('month_number', 'bathingsoap', data=dataset, label='Bathingsoap Sales Data',c='r', marker='o',mec='black', linewidth=3)
plt.plot('month_number', 'shampoo', data=dataset, label='Shampoo Sales Data',c='brown', marker='o',mec='black', linewidth=3)
plt.plot('month_number', 'moisturizer', data=dataset, label='Moisturizer Sales Data',c='pink', marker='o',mec='black', linewidth=3)
plt.xlabel('Months')
plt.ylabel('Sales units in number')
plt.xticks(dataset['month_number'].tolist())
plt.yticks([1000, 2000, 4000, 6000, 8000, 10000, 12000, 15000, 18000])
plt.legend()
plt.grid(ls = ":")
plt.show()

# %% [markdown]
# **Analysis:** Bathing soap sales are the highest and the sales of moisturizer is the lowest according to the plotted graphs.
#
# The sales of bathing soap is increasing from september to december

# %% [markdown]
# #4. Read toothpaste sales data of each month and show it using a scatter plot.

# %%
#Matplotlib Scatter
plt.figure(figsize=(7,5))
plt.scatter(dataset['month_number'],dataset['toothpaste'], c='brown')
plt.grid(ls= ":")

# %% [markdown]
# **Analysis:** The toothpaste sales is highest in October and least in March and May.

# %% [markdown]
# #5. Read face cream and facewash product sales data and show it using the bar chart.

# %%
monthList  = dataset['month_number'].tolist()
faceCremSalesData   = dataset['facecream'].tolist()
faceWashSalesData   = dataset['facewash'].tolist()

plt.figure(figsize=(9.5,7))
plt.bar(monthList, faceCremSalesData, width= 0.40, color='Pink', label = 'Face Cream sales data', align='edge')
plt.bar(monthList, faceWashSalesData, width= -0.40, color='Skyblue', label = 'Face Wash sales data', align='edge')
plt.xlabel('Month Number')
plt.ylabel('Sales units in number')
plt.legend(loc='upper left')
plt.title(' Sales data')

plt.xticks(monthList)
plt.grid(True, linewidth= 0.5, linestyle=":")
plt.title('Facewash and facecream sales data')
plt.show()

# %% [markdown]
# **Analysis:** Face cream sales is more than face wash sales in every month.
#
# Face cream sales went highest in august and lowest in March
#
# Face wash sales went higest in November and least in April and July

# %% [markdown]
# #6. Read sales data of bathing soap of all months and show it using a bar chart. Save this plot to your hard disk

# %%
save = plt.bar(monthList, dataset['bathingsoap'].tolist())
plt.xticks(monthList)
plt.savefig('D05-Prac4.png')

# %% [markdown]
# **Analysis:** The sales of bathing soap is increasing from september to december, and lowest in month of Feburary.

# %% [markdown]
# #7. Read the total profit of each month and show it using the histogram to see the most common profit ranges

# %%
plt.figure(figsize=(10,6))
plt.hist(dataset['total_profit'], bins=10, label = 'Profit data', color='grey')
plt.xlabel('Total profit')
plt.ylabel('Month number')
plt.title('Profit data')
plt.grid(ls=':')
plt.show()

# %% [markdown]
# **Analysis:** Goes highest in the fourth month and stays lowest in January
#
# The most common profit range lies between 150000-320000 , 340000-370000 and 390000-430000 where as most profit lies within the range 210000-230000.

# %% [markdown]
# #8. Calculate total sale data for last year for each product and show it using a Pie chart as well as 3D pie chart

# %%
plt.figure(figsize=(10, 6))
categories = dataset.columns[1:7]
sales_data = [dataset['facecream'].sum(), dataset['facewash'].sum(), dataset['toothpaste'].sum(),
              dataset['bathingsoap'].sum(), dataset['shampoo'].sum(), dataset['moisturizer'].sum()]
plt.pie(sales_data, labels=categories, autopct='%1.1f%%')
plt.legend(loc='lower right')

# %% [markdown]
# **Analysis:** The sales of bathing soap is highest last year and the sales of moisturizer and facewash is same and lowest.

# %% [markdown]
# #9. Read Bathing soap facewash of all months and display it using the Subplot

# %%
plt.figure(figsize=(10, 6))
f, axarr = plt.subplots(2, sharex=True)
monthList  = dataset['month_number'].tolist()
bathingsoap   = dataset['bathingsoap'].tolist()
faceWashSalesData   = dataset['facewash'].tolist()
axarr[0].plot(monthList, bathingsoap, label='Bathing sales data', marker='o', lw=3)
axarr[0].set_title('Sales data of  a Bathingsoap')

axarr[1].plot(monthList, faceWashSalesData, label = 'Face Wash Sales Data', c='r', marker='o', lw=3)
axarr[1].set_title('Sales data of  a facewash')
# Out:
# Text(0.5, 1.0, 'Sales data of  a facewash')

# %% [markdown]
# **Analysis:** Sales of bathingsoap is highest in december while lowest in februrary while that of facewash is highest in november and lowest in july.

# %% [markdown]
# #10. Read all product sales data and show it using the stack plot.

# %%
cream_sales = dataset['facecream'].tolist()
wash_sales = dataset['facewash'].tolist()
toothpaste_sales = dataset['toothpaste'].tolist()
bathingsoap_sales = dataset['bathingsoap'].tolist()
shampoo_sales = dataset['shampoo'].tolist()
moisturizer_sales = dataset['moisturizer'].tolist()
plt.stackplot(monthList, cream_sales, wash_sales, toothpaste_sales, bathingsoap_sales,
              shampoo_sales, moisturizer_sales, colors=['blue', 'orange', 'pink', 'green', 'purple', 'c'])

# %% [markdown]
# **Analysis:** Stackplot is used to draw a stacked area plot. It displays the complete data for visualization.

# %% [markdown]
# #EXTRA QUESTIONS:

# %% [markdown]
# 1) Plot Simple bar chart showing popularity of Programming Languages. Languages =['Python', 'SQL', 'Java', 'C++', 'JavaScript'] Popularity = [56, 39, 34, 34, 29] Security = [44 ,36 ,55, 50, 42] Plot Multiple Bars showing Popularity and Security of major Programming Languages. Also Create Horizontal bar chart using barh function.

# %%
Languages =['Python', 'SQL', 'Java', 'C++', 'JavaScript']

Popularity = [56, 39, 34, 34, 29]

Security = [44 ,36 ,55, 50, 42]

plt.subplot(2,1,1)

plt.bar(Languages, Popularity, width=0.5, color = 'orange', align='center')

plt.xlabel('Languages')

plt.ylabel('Popularity')

plt.legend(['Popularity'])

plt.show()

plt.subplot(2,1,2)

plt.bar(Languages, Security, width=0.5, color = 'red', align='center')

plt.xlabel('Languages')

plt.ylabel('Security')

plt.legend(['Security'])

plt.show()

# %%
#Horizontal Bar

Languages =['Python', 'SQL', 'Java', 'C++', 'JavaScript']

Popularity = [56, 39, 34, 34, 29]

Security = [44 ,36 ,55, 50, 42]

plt.subplot(2,1,1)

plt.barh(Languages, Popularity, color = 'g', align='center')

plt.xlabel('Languages')

plt.ylabel('Popularity')

plt.legend(['Popularity'])

plt.show()

plt.subplot(2,1,2)

plt.barh(Languages, Security, color = 'red', align='center')

plt.xlabel('Languages')

plt.ylabel('Security')

plt.legend(['Security'])

plt.show()

# %% [markdown]
# 2) Plot Histogram, we have a sample data of Students marks of various Students, we will try to plot number of Students by marks range and try to figure out how many Students are average, below-average and Excellent. Marks = [ 61,86,42,46,73,95,65,78,53,92,55,69,70,49,72,86,64] Histogram showing Below Average, Average and Excellent distribution 40-60: Below Average 60-80: Average 80-100: Excellent

# %%
Marks = np.array([61,86,42,46,73,95,65,78,53,92,55,69,70,49,72,86,64])

below_avg = Marks[np.logical_and(Marks >= 40, Marks < 60)]

avg_marks = Marks[np.logical_and(Marks >= 60, Marks < 80)]

exe_marks = Marks[np.logical_and(Marks >= 80, Marks <= 100)]

plt.hist(Marks)

plt.show()

print('Below Average Students Are : ',below_avg.size)

print('Average Students Are : ',avg_marks.size)

print('Execelent Students Are : ',exe_marks.size)
# Out:
# Below Average Students Are :  5
# Average Students Are :  8
# Execelent Students Are :  4

# %% [markdown]
# 3)  Titanic Data Set Download Data
#  Load the data file
#  (i) Create a pie chart presenting the male/female proportion
#  (ii) Create a scatterplot with the Fare paid and the Age, differ the plot color by gender

# %%
df=pd.read_csv('/content/drive/MyDrive/dh&v lab/titanic.csv',sep=',',header='infer')
df.head()
df['Sex']
x = df.Sex.value_counts()
x
plt.pie(x)
plt.legend(['Male','Female'])
plt.title('Male And Female Proportion')
plt.show()
male = df[df['Sex']=='male']
male.Sex.value_counts()
female = df[df['Sex']=='emale']
female.Sex.value_counts()
plt.scatter(male.Fare, male.Age, label = 'Male', marker = '*')
plt.scatter(female.Fare, female.Age, label = 'Female', marker = '^')
plt.legend()
plt.xlabel('Fare')
plt.ylabel('Age')
# Out:
# Text(0, 0.5, 'Age')

# %% [markdown]
# 4) Create a figure of size 15x8 with two subplots, top and bottom.
# Draw two lines in the top axes, one green and one orange.
# Add a legend for the top plot, Green and Orange. Put this legend in the top-middle of graph.
# Extra Challenge: In the bottom axes, create a graph of only the data points, marked by circles,
# but with no line connecting the points.

# %%
df={'a':[0,1,2,3,4],'b':[44,47,64,67,67],'c':[47,64,82,99,88],'d':[17,79,4,42,58]}
df = pd.DataFrame(df)
df
# Out:
#    a   b   c   d
# 0  0  44  47  17
# 1  1  47  64  79
# 2  2  64  82   4
# 3  3  67  99  42
# 4  4  67  88  58

# %%
fig, ax = plt.subplots(2, 1, figsize=(15,8))

ax[0].plot(df.index.values, df['a'], c='green')
ax[0].plot(df.index.values, df['b'], c='orange')
ax[0].legend(loc=9)

ax[1].plot(df.index.values, df['c'], marker='o', lw=0)
# Out:
# No handles with labels found to put in legend.

# %% [markdown]
# 5) Create a figure with three subplots, aligned vertically.
# Create a bar graph for a and b on the first two, but at the last one draw both a and b, but put b
# on top of a! (Hint: use the bottom argument in the bar function)
# Make sure the color for a and b are consistent in all the subplots!
# Extra Challenge: Write the magnitude of each bar on top of *it*

# %%
fig, ax = plt.subplots(3, 1, figsize=(15,18))
ax[0].bar(df.index.values, df['a'])
for i in range(df.shape[0]):
    ax[0].text(i, df['a'][i]+1, df['a'][i], horizontalalignment='center')
ax[0].legend('a')  
ax[1].bar(df.index.values, df['b'])
for i in range(df.shape[0]):
    ax[1].text(i, df['b'][i]+1, df['b'][i], horizontalalignment='center')
ax[1].legend('b')
ax[2].bar(df.index.values, df['a'])
ax[2].bar(df.index.values, df['b'], bottom=df['a'])
for i in range(df.shape[0]):
    ax[2].text(i, df['a'][i]+df['b'][i]+1, df['a'][i]+df['b'][i], horizontalalignment='center')
ax[2].legend(['a','b'])

# %% [markdown]
# 6) Visualize the mock data given below.
# Create bars to represent the turnover for each market.
# Use labels to make sure your audience understands the graph.
# Extra Challenge: On the opposite axis, draw a line to show each market share. (Hint:
# use ax.twinx())

# %%
np.random.seed(0)
turnover_data=pd.DataFrame({'boardid' : ['DAY', 'DAY_X', 'DAY_U', 'TSE'],'turnover' : np.random.randint(1e6, 1e9, 4)})
turnover_data = turnover_data.sort_values(by='turnover').reset_index().drop('index', axis=1)
turnover_data['turnover_simplified'] = turnover_data['turnover'] // 1000000
turnover_data['market_share'] = round((turnover_data['turnover'] / sum(turnover_data['turnover'])*100), 1)
turnover_data
# Out:
#   boardid   turnover  turnover_simplified  market_share
# 0     DAY  210652396                  210          10.8
# 1   DAY_X  399764591                  399          20.6
# 2     TSE  405868288                  405          20.9
# 3   DAY_U  925231285                  925          47.7

# %%
fig, ax1 = plt.subplots(figsize=(15,10))
ax1.bar(turnover_data['boardid'], turnover_data['turnover'], width=0.5, color='lightgreen')
for i in range(turnover_data.shape[0]):
    ax1.text(turnover_data['boardid'][i], turnover_data['turnover'][i]+1e7, str(turnover_data['turnover_simplified'][i])+'M', fontsize=15, horizontalalignment='center')
ax1.set_title('Turnover Data', fontsize=20)
ax1.set_ylabel('Turnover Values(Million)', fontsize=20)
ax1.set_ylim(0, max(turnover_data['turnover']+1e8))
ax2 = ax1.twinx()
ax2.plot(turnover_data['boardid'], turnover_data['market_share'], c='red', lw=4, marker='o')
for i in range(turnover_data.shape[0]):
    ax2.text(turnover_data['boardid'][i], turnover_data['market_share'][i]+1, str(turnover_data['market_share'][i])+'%', fontsize=15, horizontalalignment='center', color='black')
